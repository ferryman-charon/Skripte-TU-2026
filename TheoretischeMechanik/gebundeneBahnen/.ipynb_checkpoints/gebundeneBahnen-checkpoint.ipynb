# %%
import numpy as np
from scipy.integrate import quad
import matplotlib.pyplot as plt

# %%
# def constans
m = 1.0
m2 = 2.0 * m 
V = 1.0
R = 1.0

m_rel = (m * m2) / (m + m2) 

E = -0.3
l = 0.5

# %%
def U(r): 
    r = np.abs(r)
    return np.where(r > R, 0, -V)

def Ueff(r):
    r = np.abs(r)
    r = np.where(r == 0.0, np.inf, r)
    return U(r) + l**2 / (2 * m_rel * r**2)

def compute_rho_bound(E, l, mu, V, R):
    E_out = l**2 / (2.0 * mu * (R**2))
    if not (E_out - V <= E < E_out):
        return None, None

    rho1 = np.sqrt(l**2 / (2.0 * mu * (E + V)))
    return rho1, R

def dphi_dr(r, l, mu, E):
    U_eff = Ueff(r)
    denom = (2.0/mu) * (E - U_eff)

    denom = np.where(denom <= 0, np.nan, denom)
    integrand = (l / (mu * r**2)) / np.sqrt(denom)
    return np.nan_to_num(integrand, nan=0.0)

# %% [markdown]
# ## Plot Potential $U_{eff}(\rho)$

# %%
rho = np.linspace(0.2, 2*R, 1000)
U_eff = U(rho) + (l**2 / (2*mu*rho**2))
plt.plot(rho, U_eff)

# %% [markdown]
# ## Solve Question 6

# %%
rho1, rho2 = compute_rho_bound(E, l, m_rel, V, R)

phi, err = quad(dphi_dr, rho1, rho2, args=(l,m_rel, E,))
delta_phi = 2*phi
delta_phi
# Out:
# 2.0536242895400183

# %%
def phi(r):
    phi, err = quad(dphi_dr, rho1, r, args=(l,m_rel, E,))
    return phi

r = np.linspace(rho1 + 1e-4, rho2, 500)
phi_vals = np.array([phi(ri) for ri in r])

# quad is very slow
plt.polar(phi_vals, r)       # use polar plot to show trajectory
plt.show()

# %%
r = np.linspace(rho1, rho2, 2000)
integrand = dphi_dr(r, l, m_rel, E)

# cumulative integral using trapezoidal rule
phi_vals = np.cumsum((integrand[:-1] + integrand[1:]) / 2 * np.diff(r))
phi_vals = np.insert(phi_vals, 0, 0.0)  # start at phi=0

phi_p = lambda n : phi_vals + n*delta_phi
phi_r = lambda n : 2*phi_vals[-1] - phi_vals[::-1]+ n * delta_phi

r_full = np.concatenate((r, r[::-1], r, r[::-1], r, r[::-1]))
phi_full = np.concatenate((phi_p(0), phi_r(0), phi_p(1), phi_r(1), phi_p(2), phi_r(2)))

plt.polar(phi_full, r_full)

min_rad = np.linspace(0, 2*np.pi,1000)
plt.polar(min_rad, np.ones_like(min_rad)*rho1)
plt.title("Closed trajectory (full radial oscillation)")
# Out:
# Text(0.5, 1.0, 'Closed trajectory (full radial oscillation)')
